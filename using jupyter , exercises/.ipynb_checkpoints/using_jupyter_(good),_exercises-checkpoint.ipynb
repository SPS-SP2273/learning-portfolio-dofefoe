# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')

#force interrupt achieved by going to Kernel>Interrupt Kernel
#alternatively, going to Anaconda command prompt and doing ctrl+C, but this shutdown the entire process instead of just this "lab"
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     print('*', end='')
#       4 #force interrupt achieved by going to Kernel>Interrupt Kernel
#       5 #alternatively, going to Anaconda command prompt and doing ctrl+C, but this shutdown the entire process instead of just this "lab"
#
# File C:\ProgramData\miniconda3\Lib\site-packages\ipykernel\iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:

# %%
print = 'PRINT'
print("hello world")

#kernel restart achieved by going to kernel>restart kernel
#print("hello world") works in new cell (below)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print = 'PRINT'
# ----> 2 print("hello world")
#       4 #kernel restart achieved by going to kernel>restart kernel
#
# TypeError: 'str' object is not callable

# %%
print("hello world")
# Out:
# hello world
